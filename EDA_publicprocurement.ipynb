# %%
# 📦 Imports y Configuración
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-Learn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Configuración Visual
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %%
data = pd.read_csv('df_maestro95_vars.csv')

# %%
data.head(5)
# Out:
#   NIVEL                        SECTOR  \
# 0    GN  TRANSPORTES Y COMUNICACIONES
# 1    GN  TRANSPORTES Y COMUNICACIONES
# 2    GN  TRANSPORTES Y COMUNICACIONES
# 3    GN                        FONAFE
# 4    GR          GOBIERNOS REGIONALES
#
#                                              ENTIDAD  CODIGO_UNICO  \
# 0   MINISTERIO DE TRANSPORTES Y COMUNICACIONES - MTC       2623129
# 1  AUTORIDAD DE TRANSPORTE URBANO PARA LIMA Y CAL...       2300242
# 2   MINISTERIO DE TRANSPORTES Y COMUNICACIONES - MTC       2233850
# 3  SERVICIO DE AGUA POTABLE Y ALCANTARILLADO DE L...       2494846
# 4                      GOBIERNO REGIONAL LA LIBERTAD       2077997
#
#    CODIGO_SNIP                                   NOMBRE_INVERSION  \
# 0      2623129  CREACION DEL SERVICIO DE TRANSITABILIDAD VIAL ...
# 1       333424  CREACION DE LA LINEA 3 DE LA RED BASICA DEL ME...
# 2       239307  CONSTRUCCION DE LA LINEA 2 Y RAMAL AV. FAUCETT...
# 3      2494846  MEJORAMIENTO Y AMPLIACION DE LOS SERVICIOS DE ...
# 4        90449                 PROYECTO CHAVIMOCHIC TERCERA ETAPA
#
#                                          NOMBRE_OPMI  \
# 0  OPMI DEL MINISTERIO DE TRANSPORTES Y COMUNICAC...
# 1  OPMI DEL MINISTERIO DE TRANSPORTES Y COMUNICAC...
# 2  OPMI DEL MINISTERIO DE TRANSPORTES Y COMUNICAC...
# 3  ORGANO ENCARGADO DE ELABORAR EL PMI DEL SERVIC...
# 4         OPMI DEL MINISTERIO DE AGRICULTURA - MINAG
#
#                                            NOMBRE_UF  \
# 0          DIRECCIÓN DE ESTUDIOS DE PROVÍAS NACIONAL
# 1               SUBDIRECCIÓN DE ESTUDIOS Y PROYECTOS
# 2               SUBDIRECCIÓN DE ESTUDIOS Y PROYECTOS
# 3  UF DEL SERVICIO DE AGUA POTABLE Y ALCANTARILLA...
# 4        PROGRAMA SUBSECTORIAL DE IRRIGACIONES - PSI
#
#                                           NOMBRE_UEI  \
# 0          DIRECCIÓN DE ESTUDIOS DE PROVIAS NACIONAL
# 1                       DIRECCIÓN DE INFRAESTRUCTURA
# 2                       DIRECCIÓN DE INFRAESTRUCTURA
# 3  UEI DEL SERVICIO DE AGUA POTABLE Y ALCANTARILL...
# 4           UEI PROGRAMA SUSECTORIAL DE IRRIGACIONES
#
#                                           NOMBRE_UEP  ...  \
# 0                             MTC- PRO VIAS NACIONAL  ...
# 1  AUTORIDAD DE TRANSPORTE URBANO PARA LIMA Y CAL...  ...
# 2  AUTORIDAD DE TRANSPORTE URBANO PARA LIMA Y CAL...  ...
# 3  SERVICIO DE AGUA POTABLE Y ALCANTARILLADO DE L...  ...
# 4   REGION LA LIBERTAD-PROYECTO ESPECIAL CHAVIMOCHIC  ...
#
#                Monto de adicionales de obra en soles  \
# 0                                                  0
# 1                                                  0
# 2  00002080760 5315773912 48637701 0900000486958 ...
# 3                                                  0
# 4                                               0000
#
#    N° de adicionales de supervisión  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
#
#    Monto de adicionales de supervisión en soles N° de deductivos de obra  \
# 0                                             0                        0
# 1                                             0                        0
# 2      0000000000000000000000000000000000000000                        0
# 3                                             0                        0
# 4                                          0000                        0
#
#        Monto de deductivos de obra en soles N° de deductivos de supervisión  \
# 0                                         0                               0
# 1                                         0                               0
# 2  0000000000000000000000000000000000000000                               0
# 3                                         0                               0
# 4                                      0000                               0
#
#   Monto de deductivos de supervisión en soles  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#                            Costo de la obra en soles  \
# 0                                                  0
# 1                                                  0
# 2  11601737 6530807034 803443422 801367365 604088...
# 3                                                  0
# 4               752840235 59752840235 59752840235 59
#
#   ¿Corresponde la transferencia  a otra entidad?  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Monto Total devengado del proyecto
# 0                        150897436 5
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
#
# [5 rows x 95 columns]

# %%
data.shape
# Out:
# (64466, 95)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64466 entries, 0 to 64465
# Data columns (total 95 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   NIVEL                                           64466 non-null  object
#  1   SECTOR                                          64466 non-null  object
#  2   ENTIDAD                                         64466 non-null  object
#  3   CODIGO_UNICO                                    64466 non-null  int64
#  4   CODIGO_SNIP                                     64466 non-null  int64
#  5   NOMBRE_INVERSION                                64466 non-null  object
#  6   NOMBRE_OPMI                                     60158 non-null  object
#  7   NOMBRE_UF                                       60598 non-null  object
#  8   NOMBRE_UEI                                      63698 non-null  object
#  9   NOMBRE_UEP                                      64451 non-null  object
#  10  SITUACION                                       64466 non-null  object
#  11  MONTO_VIABLE                                    64454 non-null  float64
#  12  COSTO_ACTUALIZADO                               64466 non-null  float64
#  13  FECHA_REGISTRO                                  64466 non-null  object
#  14  FUNCION                                         64466 non-null  object
#  15  FECHA_VIABILIDAD                                64455 non-null  object
#  16  TIPO_INVERSION                                  64466 non-null  object
#  17  DES_MODALIDAD                                   62572 non-null  object
#  18  REGISTRADO_PMI                                  64466 non-null  object
#  19  EXPEDIENTE_TECNICO                              64466 non-null  object
#  20  INFORME_CIERRE                                  64464 non-null  object
#  21  TIENE_F9                                        64466 non-null  object
#  22  PRIMER_DEVENGADO                                61109 non-null  float64
#  23  ULTIMO_DEVENGADO                                61109 non-null  float64
#  24  DEVEN_ACUMUL_ANIO_ANT                           64466 non-null  float64
#  25  DEV_ANIO_ACTUAL                                 64466 non-null  float64
#  26  PIM_ANIO_ACTUAL                                 64466 non-null  int64
#  27  SALDO_EJECUTAR                                  64466 non-null  float64
#  28  TIENE_F8                                        64466 non-null  object
#  29  ETAPA_F8                                        62350 non-null  object
#  30  TIENE_F12B                                      64466 non-null  object
#  31  TIENE_AVAN_FISICO                               64466 non-null  object
#  32  AVANCE_FISICO                                   45019 non-null  float64
#  33  AVANCE_EJECUCION                                56270 non-null  float64
#  34  ULT_FEC_DECLA_ESTIM                             50375 non-null  object
#  35  DEPARTAMENTO                                    64466 non-null  object
#  36  PROVINCIA                                       64465 non-null  object
#  37  DISTRITO                                        64459 non-null  object
#  38  UBIGEO                                          64343 non-null  float64
#  39  LATITUD                                         64195 non-null  float64
#  40  LONGITUD                                        64194 non-null  float64
#  41  FEC_INI_EJECUCION                               59572 non-null  object
#  42  FEC_FIN_EJECUCION                               59573 non-null  object
#  43  FEC_INI_EJEC_FISICA                             58868 non-null  object
#  44  FEC_FIN_EJEC_FISICA                             58868 non-null  object
#  45  NUM_HABITANTES_BENEF                            45409 non-null  float64
#  46  MONTO_ET_F8                                     59032 non-null  float64
#  47  ANIO_PROCESO                                    64466 non-null  int64
#  48  Código INFOBRAS                                 64466 non-null  int64
#  49  N° obras pertenecientes a la inversión          64466 non-null  int64
#  50  Estado de ejecución                             64466 non-null  object
#  51  Existe Paralización                             64466 non-null  bool
#  52  N° de controversias                             64466 non-null  int64
#  53  N° Comentarios ciudadanos                       64466 non-null  int64
#  54  Fecha de registro de avance                     44481 non-null  object
#  55  Fecha inicio de labores                         45918 non-null  object
#  56  N° de modificaciones                            64466 non-null  int64
#  57  Número de dias paralizado                       64466 non-null  float64
#  58  Fecha inicio supervision                        45362 non-null  object
#  59  Modalidad de ejecución de la obra               64466 non-null  object
#  60  ¿Tiene recepción total?                         64466 non-null  bool
#  61  ¿Tiene liquidación de obra?                     64466 non-null  bool
#  62  Plazo de ejecución (en dias)                    46071 non-null  float64
#  63  N° Informes de control                          64466 non-null  int64
#  64  Monto del contrato  en soles                    64466 non-null  object
#  65  ¿Corresponde a un saldo de Obra?                64466 non-null  bool
#  66  Naturaleza de la obra                           64459 non-null  object
#  67  Tipo de obra - Clasificador Nivel 1             64466 non-null  object
#  68  Tipo de obra - Clasificador Nivel 2             64466 non-null  object
#  69  Tipo de obra - Clasificador Nivel 3             64466 non-null  object
#  70  Marca Reactivación Economicas (Si/No)           64466 non-null  bool
#  71  N° de Veedurías Ciudadanas                      64466 non-null  int64
#  72  ¿Es una obra de carácter reservado?             64466 non-null  bool
#  73  Costo de obra en soles según ET en soles        64466 non-null  object
#  74  Documento de aprobación de expediente           51967 non-null  object
#  75  Monto del contrato  en soles.1                  64466 non-null  object
#  76  Fecha finalización programada de obra           46071 non-null  object
#  77  Monto de valorización Programado Acumulado      64466 non-null  object
#  78  Monto de valorización Ejecutado Acumulado       64466 non-null  object
#  79  Porcentaje de ejecución financiera              44478 non-null  float64
#  80  Monto de ejecución financiera de la obra        64466 non-null  object
#  81  N° días de modificaciones de plazo              64466 non-null  int64
#  82  Nuevo Plazo de ejecución (en dias)              64466 non-null  int64
#  83  Fecha finalización reprogramada de obra         46774 non-null  object
#  84  N° de adicionales de obra                       64466 non-null  int64
#  85  Monto de adicionales de obra en soles           64466 non-null  object
#  86  N° de adicionales de supervisión                64466 non-null  int64
#  87  Monto de adicionales de supervisión en soles    64466 non-null  object
#  88  N° de deductivos de obra                        64466 non-null  int64
#  89  Monto de deductivos de obra en soles            64466 non-null  object
#  90  N° de deductivos de supervisión                 64466 non-null  int64
#  91  Monto de deductivos de supervisión en soles     64466 non-null  int64
#  92  Costo de la obra en soles                       64466 non-null  object
#  93  ¿Corresponde la transferencia  a otra entidad?  64466 non-null  bool
#  94  Monto Total devengado del proyecto              64466 non-null  object
# dtypes: bool(7), float64(17), int64(18), object(53)
# memory usage: 43.7+ MB
